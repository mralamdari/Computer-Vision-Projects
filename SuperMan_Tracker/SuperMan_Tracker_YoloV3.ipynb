# %% [markdown]
# <a href="https://colab.research.google.com/github/mralamdari/Computer-Vision-Projects/blob/main/SuperMan_Tracker_YoloV3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Step 0: Essentials

# %%
import os
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def imShow(path):
  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()

# %% [markdown]
# ##Download Some Video Clips of superman from this [Source](https://lyricslive24.com/superman-action-scene/)

# %%
#Sample Videos
# !wget https://lived2.lyricslive24.com/mp4regular/play/eDdtQk1BNzNoRlgxcjk4dFdzUTEwUT09/Superman-vs-Wonder-women-fight-scene-WhatsApp-status---justice-league--Superman.mp4
# !wget https://lived2.lyricslive24.com/mp4regular/play/VVZjNlFoZEJOaHk2Y0U5cUFjNWVmUT09/SuperMan-Returns---WhatsApp-Status--Fight-Scene-.mp4
# !wget https://vfss.b-cdn.net/library/S/Superman-Status-Video/Superman-attitude-full-screen-Shorts.mp4
# !wget https://lived2.lyricslive24.com/mp4regular/play/T0dLK3ZOTXllVW5IMVJqMUtNZzNXZz09/Whatsapp-Superman-Status-Scene-Fight.mp4
# !wget https://lived2.lyricslive24.com/mp4regular/play/S0J1WVVIV3A3R1ZJN3hZeDRMb3dNZz09/superman-amazing-fighting-scene-whatsApp-status-short.mp4
# !wget https://lived2.lyricslive24.com/mp4regular/play/SXpXaGFxZy8wTlVxS3lGRUNvZldZUT09/Superman-Superman-whatsapp-Trinity-wonder-Batman-status-Batman-woman-scene-from-v.mp4

# %% [markdown]
# #Step 1: Darknet
# To use yolo model, you can get it easily from darknet or you can create a yolo model from scratch

# %%
#clone Darknet
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15490, done.
# remote: Total 15490 (delta 0), reused 0 (delta 0), pack-reused 15490
# Receiving objects: 100% (15490/15490), 14.08 MiB | 23.60 MiB/s, done.
# Resolving deltas: 100% (10408/10408), done.

# %%
# change makefile to have gpu and opencv enabled
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# Out:
# /content/darknet

# %%
#Build(make) Darknet
# !make

# %% [markdown]
# #Step 2: Dataset
# you can get The Dataset From [Kaggle](https://www.kaggle.com/datasets/mralamdari/super-man-images-dataset)

# %%
# %cd /content/
os.environ['KAGGLE_CONFIG_DIR'] = '/content/'
# !kaggle datasets download -d mralamdari/super-man-images-dataset
# !unzip \*.zip && rm *.zip

# %% [markdown]
# 1. Create obj.names
# 2. Move images to /content/darknet/
# 3. Create train.txt in /content/darknet/data/obj folder

# %%
NUM_CLASSES = 1

os.rename('/content/SuperMan/classes.txt', '/content/darknet/data/obj.names')

os.rename('/content/SuperMan', '/content/darknet/data/obj/')

data_path='/content/darknet/data/'
with open(f'{data_path}train.txt', 'w+') as data_file:
      for image_file in os.listdir(f'{data_path}obj'):
          if image_file.endswith('.jpg'):
              data_file.write(f'{os.path.join(f"{data_path}obj", image_file)}\n')
data_file.close()

# %% [markdown]
# Adjust yolov3-custom to trainning

# %%
with open('/content/darknet/cfg/yolov3.cfg', 'r+') as f:
    config_files = f.readlines()

config_files[2] = '#'+config_files[2] # batch=1
config_files[3] = '#'+config_files[3] # subdivisions=1

config_files[5] = config_files[5][2:]  # batch=64
config_files[6] = config_files[6][2:]  # subdivisions=16


num_classes=NUM_CLASSES
max_batches = 4000 if num_classes==1 else num_classes*2000
config_files[19] = f'max_batches={max_batches}\n'
config_files[21] = f'steps={max_batches*8//10},{max_batches*9//10}\n'


for i, j in enumerate(config_files):
    if j == '[yolo]\n':
        config_files[i-4] = f"filters={3*(5+num_classes)}\n" # convolutional filters
        config_files[i+3] = f"classes={num_classes}\n"       # yolo_classes
        config_files[i+8] = 'random=1\n'                     # yolo_random  0 or 1


with open('/content/darknet/cfg/yolov3-custom.cfg', 'w+') as f:
    f.writelines(config_files)

# %% [markdown]
# Create Obj.data

# %%
with open('/content/darknet/data/obj.data', 'w+') as obj_data:
  odata = f"""classes={num_classes}
  train=/content/darknet/data/train.txt
  valid=/content/darknet/data/test.txt
  names=/content/darknet/data/obj.names
  backup=/content/drive/MyDrive/yolov3_backup
  """
  obj_data.write(odata)

os.makedirs('/content/drive/MyDrive/yolov3_backup', exist_ok=True)

# %% [markdown]
# #Step 3: Model

# %% [markdown]
# Get pre-trained weights for yolo

# %%
# %cd /content/darknet
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# /content/darknet
# --2022-09-13 07:33:16--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  45.8MB/s    in 3.7s
#
# 2022-09-13 07:33:20 (41.7 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %% [markdown]
# ### Train from scratch
#
# #####Use this code, so colab won't crash after being inactive for more than 10 mins;
#
#     function ClickConnect(){
#     console.log("Working");
#     document.querySelector("colab-toolbar-button#connect").click()
#     }
#     setInterval(ClickConnect,60000)

# %%
# !./darknet detector train /content/darknet/data/obj.data /content/darknet/cfg/yolov3-custom.cfg /content/darknet/darknet53.conv.74 -dont_show

# %%
imShow('chart.png')

# %% [markdown]
# ### Train from where you ceased training with saved weights.

# %%
# %cd /content/darknet
# !./darknet detector train /content/darknet/data/obj.data /content/darknet/cfg/yolov3-custom.cfg /content/drive/MyDrive/yolov3_backup/yolov3-custom_last.weights -dont_show

# %%
imShow('chart.png')

# %% [markdown]
# Adjust yolov3-custom.cfg for testing

# %%
with open('/content/darknet/cfg/yolov3-custom.cfg', 'r+') as f:
    config_files = f.readlines()

config_files[5] = '#'+config_files[5] # batch=64
config_files[6] = '#'+config_files[6] # subdivisions=16

config_files[2] = config_files[2][2:]  # batch=1
config_files[3] = config_files[3][2:]  # subdivisions=1

with open('/content/darknet/cfg/yolov3-custom.cfg', 'w+') as f:
    f.writelines(config_files)

# %% [markdown]
# ##Predict

# %% [markdown]
# ###Image Prediction

# %%
# %cd /content/darknet
# !./darknet detector test /content/darknet/data/obj.data /content/darknet/cfg/yolov3-custom.cfg /content/drive/MyDrive/yolov3_backup/yolov3-custom_last.weights /content/darknet/data/obj/460.jpg -thresh 0.8 -dont_show
# Out:
# /content/darknet
#  CUDA-version: 11010 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
# batch: Using default '1'
# subdivisions: Using default '1'
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5,  wt = 0, wn = 0, outputs: 104 x 104 x 128 0.001 BF
#    9 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#   10 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#   11 Shortcut Layer: 8,  wt = 0, wn = 0, outputs: 104 x 104 x 128 0.001 BF
#   12 conv    256       3 x 3/ 2    104 x 104 x 128 ->   52 x  52 x 256 1.595 BF
#   13 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   14 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   15 Shortcut Layer: 12,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   16 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   17 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   18 Shortcut Layer: 15,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   19 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   20 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   21 Shortcut Layer: 18,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   22 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   23 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   24 Shortcut Layer: 21,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   25 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   26 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   27 Shortcut Layer: 24,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   28 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   29 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   30 Shortcut Layer: 27,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   31 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   32 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   33 Shortcut Layer: 30,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   34 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   35 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   36 Shortcut Layer: 33,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   37 conv    512       3 x 3/ 2     52 x  52 x 256 ->   26 x  26 x 512 1.595 BF
#   38 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   39 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   40 Shortcut Layer: 37,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   41 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   42 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   43 Shortcut Layer: 40,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   44 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   45 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   46 Shortcut Layer: 43,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   47 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   48 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   49 Shortcut Layer: 46,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   50 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   51 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   52 Shortcut Layer: 49,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   53 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   54 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   55 Shortcut Layer: 52,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   56 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   57 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   58 Shortcut Layer: 55,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   59 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   60 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   61 Shortcut Layer: 58,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   62 conv   1024       3 x 3/ 2     26 x  26 x 512 ->   13 x  13 x1024 1.595 BF
#   63 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   64 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   65 Shortcut Layer: 62,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   66 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   67 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   68 Shortcut Layer: 65,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   69 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   70 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   71 Shortcut Layer: 68,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   72 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   73 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   74 Shortcut Layer: 71,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   75 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   76 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   77 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   78 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   79 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   80 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   81 conv     18       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x  18 0.006 BF
#   82 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
#   83 route  79 		                           ->   13 x  13 x 512
#   84 conv    256       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 256 0.044 BF
#   85 upsample                 2x    13 x  13 x 256 ->   26 x  26 x 256
#   86 route  85 61 	                           ->   26 x  26 x 768
#   87 conv    256       1 x 1/ 1     26 x  26 x 768 ->   26 x  26 x 256 0.266 BF
#   88 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   89 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   90 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   91 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   92 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   93 conv     18       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x  18 0.012 BF
#   94 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
#   95 route  91 		                           ->   26 x  26 x 256
#   96 conv    128       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 128 0.044 BF
#   97 upsample                 2x    26 x  26 x 128 ->   52 x  52 x 128
#   98 route  97 36 	                           ->   52 x  52 x 384
#   99 conv    128       1 x 1/ 1     52 x  52 x 384 ->   52 x  52 x 128 0.266 BF
#  100 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  101 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#  102 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  103 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#  104 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  105 conv     18       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x  18 0.025 BF
#  106 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
# Total BFLOPS 65.304
# avg_outputs = 516723
#  Allocate additional workspace_size = 52.43 MB
# Loading weights from /content/drive/MyDrive/yolov3_backup/yolov3-custom_last.weights...
#  seen 64, trained: 256 K-images (4 Kilo-batches_64)
# Done! Loaded 107 layers from weights-file
#  Detection layer: 82 - type = 28
#  Detection layer: 94 - type = 28
#  Detection layer: 106 - type = 28
# /content/darknet/data/obj/460.jpg: Predicted in 40.096000 milli-seconds.
# SuperMan: 99%

# %%
imShow('predictions.jpg')

# %% [markdown]
# ###Video Prediction

# %%
# %cd /content/darknet
output_video = '/content/results.avi'

# !./darknet detector demo /content/darknet/data/obj.data /content/darknet/cfg/yolov3-custom.cfg /content/drive/MyDrive/yolov3_backup/yolov3-custom_last.weights /content/superman-amazing-fighting-scene-whatsApp-status-short.mp4 -dont_show -i 0 -out_filename $output_video
# Out:
# Streaming output truncated to the last 5000 lines.
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.8 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.9 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.8 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.8 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.8 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.9 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.9 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.0 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.8 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.9 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.0 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.1 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.0 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.0 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.0 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.0 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.6 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.7 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.9 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.9 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.8 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.8 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.7 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.8 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.6 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.6 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.6 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.6 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.5 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.4 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.4 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.4 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.5 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.6 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.7 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.8 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.7 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.6 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 38%
#
# FPS:39.6 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 88%
#
# FPS:39.7 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 79%
#
# FPS:39.4 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 44%
#
# FPS:39.7 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 42%
#
# FPS:40.0 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.1 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.3 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.3 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.4 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.4 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.5 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.6 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 30%
#
# FPS:40.6 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 35%
#
# FPS:40.7 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 26%
#
# FPS:40.6 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 30%
#
# FPS:40.7 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.8 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.9 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.1 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.5 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.7 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 26%
#
# FPS:40.8 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.6 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 70%
#
# FPS:40.6 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.8 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:41.1 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 61%
#
# FPS:41.0 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 66%
#
# FPS:40.8 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 70%
#
# FPS:40.5 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 67%
#
# FPS:40.4 	 AVG_FPS:39.5
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 51%
#
# FPS:40.3 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 51%
#
# FPS:40.2 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 89%
#
# FPS:40.2 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 70%
#
# FPS:40.3 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 83%
#
# FPS:40.3 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 80%
#
# FPS:40.2 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 83%
#
# FPS:40.1 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 78%
#
# FPS:40.0 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 95%
#
# FPS:39.9 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 96%
#
# FPS:39.8 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 90%
#
# FPS:39.8 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 89%
#
# FPS:40.0 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 77%
#
# FPS:39.9 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 94%
#
# FPS:40.0 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 96%
#
# FPS:40.0 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 97%
#
# FPS:40.0 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 97%
#
# FPS:40.1 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 98%
#
# FPS:40.1 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:39.9 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 88%
#
# FPS:39.9 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 98%
#
# FPS:40.0 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 76%
#
# FPS:40.0 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 72%
#
# FPS:39.9 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 90%
#
# FPS:39.9 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 89%
#
# FPS:40.0 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 92%
#
# FPS:39.9 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 61%
#
# FPS:39.8 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 59%
#
# FPS:39.5 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 91%
#
# FPS:39.6 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 96%
#
# FPS:39.5 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 79%
#
# FPS:39.3 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 97%
#
# FPS:39.3 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 94%
#
# FPS:39.4 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 95%
#
# FPS:39.2 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 98%
#
# FPS:39.1 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 94%
#
# FPS:39.2 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 98%
#
# FPS:39.0 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 98%
#
# FPS:39.0 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 97%
#
# FPS:39.0 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 97%
#
# FPS:39.3 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:39.3 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:39.2 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 98%
#
# FPS:39.2 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 97%
#
# FPS:39.3 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 96%
#
# FPS:39.2 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 90%
#
# FPS:39.0 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 85%
#
# FPS:39.0 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 87%
#
# FPS:39.0 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 96%
#
# FPS:39.0 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 96%
#
# FPS:39.1 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:39.1 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:39.1 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:39.1 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:39.2 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:39.2 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:39.3 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 95%
#
# FPS:39.2 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 95%
#
# FPS:39.1 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 97%
#
# FPS:39.1 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 98%
#
# FPS:39.0 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.0 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.0 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.1 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.1 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.1 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.2 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.4 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.4 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.2 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.2 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.4 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.4 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.3 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.2 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.3 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.4 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.1 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.3 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.5 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.5 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.3 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.2 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.2 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.3 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.4 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.4 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.5 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:38.8 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:38.9 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.1 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.0 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:38.5 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:38.7 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.0 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:38.8 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:38.8 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:38.8 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:38.9 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:38.9 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.0 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.1 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.2 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.2 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.1 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.2 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.3 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:38.8 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.1 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.5 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.6 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.5 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.5 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.5 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.7 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 52%
#
# FPS:39.8 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.0 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.1 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.4 	 AVG_FPS:40.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.2 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.2 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.4 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.4 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.5 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.5 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.5 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.6 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.7 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.8 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.9 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.9 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 97%
#
# FPS:40.9 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 46%
#
# FPS:41.1 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:41.0 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:41.2 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:41.1 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:41.1 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 59%
#
# FPS:41.1 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 28%
#
# FPS:41.0 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:41.0 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:41.1 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:41.1 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:41.1 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:41.0 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:41.2 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 83%
#
# FPS:41.3 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 81%
#
# FPS:41.4 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:41.3 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 70%
#
# FPS:41.4 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 96%
#
# FPS:41.0 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.4 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.4 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 95%
#
# FPS:40.5 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.6 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:40.6 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.6 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.6 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.7 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 47%
#
# FPS:40.7 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.7 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.7 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.8 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.7 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.7 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.6 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.5 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.6 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.7 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.8 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.1 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.3 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.6 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.6 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.5 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.5 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.5 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.7 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.7 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.6 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.6 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.6 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.8 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.9 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.7 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.5 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.8 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:41.0 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:41.2 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:41.4 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:41.3 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:41.1 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:41.0 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.3 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.5 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.5 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.6 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.6 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.6 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.6 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.6 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.7 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.7 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.6 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.6 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.6 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.5 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.1 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.3 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.5 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.5 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.5 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.5 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.6 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.6 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.7 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.7 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.7 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.3 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.3 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.4 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.6 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.6 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.8 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:41.0 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:41.1 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.9 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.9 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:41.0 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:41.2 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:41.0 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:41.1 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:41.2 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:41.2 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.6 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.5 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.6 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.8 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.9 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 73%
#
# FPS:40.9 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 79%
#
# FPS:40.7 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 45%
#
# FPS:40.6 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 40%
#
# FPS:40.7 	 AVG_FPS:39.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 78%
#
# FPS:40.7 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 39%
#
# FPS:40.8 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.8 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.8 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.1 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.1 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 68%
#
# FPS:40.3 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 40%
#
# FPS:40.3 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 41%
#
# FPS:40.4 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 36%
#
# FPS:40.5 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 65%
#
# FPS:40.6 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 54%
#
# FPS:40.6 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 75%
#
# FPS:40.4 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 77%
#
# FPS:40.3 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 89%
#
# FPS:40.4 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 92%
#
# FPS:40.5 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 94%
#
# FPS:40.6 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 95%
#
# FPS:40.6 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 95%
#
# FPS:40.6 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 96%
#
# FPS:40.7 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 95%
#
# FPS:40.7 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 95%
#
# FPS:40.6 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 94%
#
# FPS:40.7 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 96%
#
# FPS:40.8 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 96%
#
# FPS:40.9 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 94%
#
# FPS:41.0 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 93%
#
# FPS:40.9 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 93%
#
# FPS:40.9 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 91%
#
# FPS:40.8 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 91%
#
# FPS:40.8 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 90%
#
# FPS:40.9 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 87%
#
# FPS:41.1 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 93%
#
# FPS:41.1 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 95%
#
# FPS:41.1 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 86%
#
# FPS:41.1 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 87%
#
# FPS:41.1 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 94%
#
# FPS:41.1 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 54%
#
# FPS:41.2 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 86%
#
# FPS:41.1 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 93%
#
# FPS:41.2 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 92%
#
# FPS:41.1 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 92%
#
# FPS:40.3 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 97%
#
# FPS:40.1 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 98%
#
# FPS:40.1 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 83%
#
# FPS:40.0 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 84%
#
# FPS:40.0 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 95%
#
# FPS:39.9 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 91%
#
# FPS:39.9 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 80%
#
# FPS:39.7 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 84%
#
# FPS:39.5 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 63%
#
# FPS:39.6 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 56%
#
# FPS:39.5 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 65%
#
# FPS:39.4 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 85%
#
# FPS:39.4 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 86%
#
# FPS:39.5 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 70%
#
# FPS:39.4 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 65%
#
# FPS:39.4 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 87%
#
# FPS:39.4 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 86%
#
# FPS:39.5 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 61%
#
# FPS:39.4 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 76%
#
# FPS:39.4 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 91%
#
# FPS:39.4 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 88%
#
# FPS:39.6 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 85%
#
# FPS:39.5 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 72%
#
# FPS:39.5 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 85%
#
# FPS:39.5 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 88%
#
# FPS:39.6 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 93%
#
# FPS:39.7 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 95%
#
# FPS:39.6 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 94%
# SuperMan: 35%
#
# FPS:39.5 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 95%
#
# FPS:39.6 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 92%
# SuperMan: 28%
#
# FPS:39.6 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 95%
# SuperMan: 68%
#
# FPS:39.6 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 74%
# SuperMan: 70%
#
# FPS:39.3 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 74%
# SuperMan: 72%
#
# FPS:39.3 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 89%
# SuperMan: 67%
#
# FPS:39.5 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 85%
# SuperMan: 77%
#
# FPS:39.4 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 93%
# SuperMan: 77%
#
# FPS:39.2 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 94%
# SuperMan: 34%
#
# FPS:39.2 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 94%
# SuperMan: 42%
#
# FPS:39.1 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 96%
# SuperMan: 28%
#
# FPS:39.0 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 90%
# SuperMan: 54%
#
# FPS:39.1 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 80%
# SuperMan: 79%
#
# FPS:39.2 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 91%
# SuperMan: 57%
#
# FPS:39.1 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 90%
# SuperMan: 56%
#
# FPS:39.1 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 93%
# SuperMan: 35%
#
# FPS:39.3 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 92%
# SuperMan: 67%
#
# FPS:39.5 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 61%
# SuperMan: 59%
#
# FPS:39.4 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 90%
#
# FPS:39.1 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 84%
#
# FPS:39.2 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 85%
#
# FPS:39.3 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 90%
#
# FPS:39.2 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 79%
# SuperMan: 26%
#
# FPS:39.1 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 75%
#
# FPS:39.0 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 88%
#
# FPS:39.2 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 90%
#
# FPS:39.1 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 59%
# SuperMan: 57%
#
# FPS:38.5 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 70%
# SuperMan: 58%
#
# FPS:38.5 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 86%
# SuperMan: 65%
#
# FPS:38.6 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 66%
# SuperMan: 53%
#
# FPS:38.7 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 62%
# SuperMan: 50%
#
# FPS:38.8 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 67%
# SuperMan: 60%
#
# FPS:38.9 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 70%
# SuperMan: 48%
#
# FPS:38.8 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 55%
# SuperMan: 44%
#
# FPS:38.6 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 51%
# SuperMan: 30%
#
# FPS:38.8 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 57%
# SuperMan: 44%
#
# FPS:38.8 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 62%
# SuperMan: 47%
#
# FPS:38.8 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 43%
# SuperMan: 37%
#
# FPS:38.9 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 60%
# SuperMan: 34%
#
# FPS:39.0 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 87%
#
# FPS:38.9 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 87%
#
# FPS:38.9 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 84%
#
# FPS:38.9 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 86%
#
# FPS:39.0 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 87%
#
# FPS:39.1 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 88%
#
# FPS:38.8 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 87%
#
# FPS:38.8 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 86%
#
# FPS:39.0 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.0 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:38.9 	 AVG_FPS:40.7
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.0 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.2 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.1 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.1 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.2 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.3 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.2 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.2 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.3 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.4 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.3 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.2 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.3 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.4 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.3 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.2 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.1 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.2 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.1 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.0 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.0 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.1 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.1 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.2 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.2 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:39.0 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.0 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:38.9 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:39.0 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 97%
#
# FPS:38.9 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 81%
#
# FPS:38.7 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 90%
#
# FPS:38.8 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 88%
#
# FPS:38.7 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 91%
#
# FPS:38.6 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 91%
#
# FPS:38.7 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 70%
#
# FPS:38.2 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 50%
#
# FPS:38.2 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 50%
#
# FPS:38.3 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 85%
#
# FPS:38.4 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 81%
#
# FPS:38.4 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 79%
#
# FPS:38.4 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 78%
#
# FPS:38.5 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 86%
#
# FPS:38.4 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 88%
#
# FPS:38.2 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 94%
#
# FPS:38.2 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 94%
#
# FPS:38.4 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 93%
#
# FPS:38.3 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 97%
#
# FPS:37.9 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 96%
#
# FPS:38.1 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 96%
#
# FPS:38.1 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:38.1 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:38.2 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 98%
#
# FPS:38.4 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 98%
#
# FPS:38.2 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:38.2 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:38.4 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:37.5 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:37.8 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:38.2 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:38.1 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:38.1 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:38.3 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:38.4 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:38.3 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:38.2 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:38.4 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:38.4 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:38.4 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:38.5 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:38.7 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:38.6 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:38.5 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:38.5 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:38.6 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:38.4 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:38.8 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.0 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.1 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:38.8 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:38.4 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:38.9 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.1 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.1 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.2 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.3 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.4 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.5 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.5 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.4 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.7 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.9 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.1 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.4 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.6 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.7 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.5 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.7 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.9 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.0 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.2 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.1 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.2 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.1 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.4 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.6 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.8 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.0 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.0 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.9 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.0 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.1 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.2 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.3 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.4 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.8 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.5 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.6 	 AVG_FPS:39.6
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 76%
#
# FPS:40.0 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.2 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 56%
#
# FPS:40.3 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.0 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.8 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.8 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.8 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.5 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.4 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.3 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:38.7 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:38.9 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 41%
#
# FPS:39.0 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:38.9 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:38.8 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:38.9 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:39.1 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:38.7 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:38.8 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:38.9 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 27%
#
# FPS:38.9 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:38.8 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:38.8 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:38.8 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:38.7 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:38.7 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:38.8 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.0 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:38.8 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:38.9 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:38.9 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:38.7 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:38.6 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:38.6 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:38.8 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 98%
#
# FPS:38.6 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 97%
#
# FPS:38.5 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 98%
#
# FPS:38.4 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 96%
#
# FPS:38.4 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:38.7 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:38.5 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:38.7 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:38.5 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:38.4 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:38.4 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:38.2 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:38.0 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:38.0 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:37.8 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:37.9 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:38.1 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:37.9 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:37.8 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:37.9 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:37.9 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:37.8 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:37.8 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:37.8 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:37.8 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:37.8 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:38.0 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:37.9 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:37.7 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:37.8 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:37.8 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:37.6 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 98%
#
# FPS:37.7 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 98%
#
# FPS:37.8 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 97%
#
# FPS:37.6 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 98%
#
# FPS:37.6 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 97%
#
# FPS:37.8 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 98%
#
# FPS:37.9 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 97%
#
# FPS:37.8 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 97%
#
# FPS:37.8 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:37.7 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 98%
#
# FPS:37.8 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:37.9 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:38.2 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:38.0 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 98%
#
# FPS:37.9 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 98%
#
# FPS:38.0 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:37.8 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:37.9 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 87%
#
# FPS:37.8 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 90%
#
# FPS:37.7 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 76%
#
# FPS:37.6 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 85%
#
# FPS:37.7 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 90%
#
# FPS:37.6 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 93%
#
# FPS:37.5 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 94%
#
# FPS:37.5 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 96%
#
# FPS:37.4 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 98%
#
# FPS:37.5 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 98%
#
# FPS:37.7 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:37.9 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:37.7 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:37.8 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:38.0 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:37.9 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:38.1 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 98%
#
# FPS:38.1 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 98%
#
# FPS:38.1 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:38.1 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:38.5 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:38.8 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:38.9 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:39.0 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:39.0 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:38.9 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:39.0 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.1 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.2 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.3 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.4 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.6 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.6 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.7 	 AVG_FPS:39.0
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.5 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.6 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.7 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.7 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.8 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.8 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.7 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.7 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.8 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.9 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 58%
#
# FPS:39.9 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 62%
#
# FPS:39.8 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 47%
#
# FPS:39.9 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 41%
#
# FPS:39.9 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 78%
#
# FPS:39.9 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 96%
#
# FPS:39.9 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 95%
#
# FPS:39.9 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:40.0 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.1 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 90%
#
# FPS:40.1 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 32%
#
# FPS:40.1 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 27%
#
# FPS:40.2 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 33%
#
# FPS:40.3 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 85%
#
# FPS:40.3 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 85%
#
# FPS:40.3 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.3 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 43%
#
# FPS:40.3 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 42%
#
# FPS:40.4 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.4 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 96%
#
# FPS:40.2 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 83%
#
# FPS:39.6 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 96%
#
# FPS:39.8 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 96%
#
# FPS:39.7 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 97%
#
# FPS:39.9 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 42%
#
# FPS:39.9 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 34%
#
# FPS:40.0 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 74%
#
# FPS:40.0 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 72%
#
# FPS:39.1 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 70%
#
# FPS:39.4 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 93%
#
# FPS:39.7 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.9 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 83%
#
# FPS:39.9 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 97%
#
# FPS:40.0 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 97%
#
# FPS:40.1 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:40.0 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.8 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:39.8 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 87%
#
# FPS:39.9 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 86%
#
# FPS:39.9 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 87%
#
# FPS:40.0 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.0 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:40.0 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 38%
#
# FPS:40.1 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 93%
#
# FPS:40.0 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 93%
#
# FPS:39.8 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 80%
#
# FPS:39.5 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 96%
#
# FPS:39.4 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:39.2 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 98%
#
# FPS:38.9 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 98%
#
# FPS:38.7 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 83%
#
# FPS:38.6 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 93%
#
# FPS:38.7 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 97%
#
# FPS:38.6 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 98%
#
# FPS:38.5 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 98%
#
# FPS:38.5 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:38.4 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:38.2 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:38.3 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:38.4 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:38.1 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:38.1 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:38.1 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 98%
#
# FPS:38.1 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:37.9 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:38.1 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:38.2 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:38.2 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:38.2 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:38.3 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:38.1 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:38.1 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:38.2 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:38.4 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:38.3 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 100%
#
# FPS:38.3 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:38.4 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Objects:
#
# SuperMan: 99%
#
# FPS:38.4 	 AVG_FPS:38.3
#
#  cvWriteFrame
# Stream closed.
# input video stream closed.
#  closing... closed!output_video_writer closed.
