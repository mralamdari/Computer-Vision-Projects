# %% [markdown]
# <a href="https://colab.research.google.com/github/mralamdari/Computer-Vision-Projects/blob/main/Batman_Tracker_YoloV4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Step 0: Essentials

# %%
import os
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def imShow(path):
  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()

# %% [markdown]
# ##Download Some Video Clips of Batman from this [Source](https://lyricslive24.com/superman-action-scene/)

# %%
#Sample Videos
# !wget https://lived2.lyricslive24.com/mp4regular/play/eDdtQk1BNzNoRlgxcjk4dFdzUTEwUT09/Superman-vs-Wonder-women-fight-scene-WhatsApp-status---justice-league--Superman.mp4
# !wget https://lived2.lyricslive24.com/mp4regular/play/VVZjNlFoZEJOaHk2Y0U5cUFjNWVmUT09/SuperMan-Returns---WhatsApp-Status--Fight-Scene-.mp4
# !wget https://vfss.b-cdn.net/library/S/Superman-Status-Video/Superman-attitude-full-screen-Shorts.mp4
# !wget https://lived2.lyricslive24.com/mp4regular/play/T0dLK3ZOTXllVW5IMVJqMUtNZzNXZz09/Whatsapp-Superman-Status-Scene-Fight.mp4
# !wget https://lived2.lyricslive24.com/mp4regular/play/S0J1WVVIV3A3R1ZJN3hZeDRMb3dNZz09/superman-amazing-fighting-scene-whatsApp-status-short.mp4
# !wget https://lived2.lyricslive24.com/mp4regular/play/SXpXaGFxZy8wTlVxS3lGRUNvZldZUT09/Superman-Superman-whatsapp-Trinity-wonder-Batman-status-Batman-woman-scene-from-v.mp4

# %% [markdown]
# #Step 1: Darknet
# To use yolo v4 model, you can get it easily from darknet or you can create a yolo v4 model from scratch

# %%
#clone Darknet
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15494, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 15494 (delta 0), reused 2 (delta 0), pack-reused 15490
# Receiving objects: 100% (15494/15494), 14.11 MiB | 11.15 MiB/s, done.
# Resolving deltas: 100% (10408/10408), done.

# %%
# change makefile to have gpu and opencv enabled
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# Out:
# /content/darknet

# %%
#Build(make) Darknet
# !make

# %% [markdown]
# #Step 2: Dataset
# you can get The Dataset From [Kaggle](https://www.kaggle.com/datasets/mralamdari/superman-or-batman)

# %%
# %cd /content/
os.environ['KAGGLE_CONFIG_DIR'] = '/content/drive/MyDrive/'
# !kaggle datasets download -d mralamdari/batman-images-dataset
# !unzip \*.zip && rm *.zip

# %% [markdown]
# 1. Create obj.names
# 2. Move images to /content/darknet/
# 3. Create train.txt in /content/darknet/data/obj folder

# %%
NUM_CLASSES = 1
picture_folder='Batman'

os.rename(f'/content/{picture_folder}/classes.txt', '/content/darknet/data/obj.names')

os.rename(f'/content/{picture_folder}', '/content/darknet/data/obj/')

data_path='/content/darknet/data/'
with open(f'{data_path}train.txt', 'w+') as data_file:
      for image_file in os.listdir(f'{data_path}obj'):
          if image_file.endswith('.jpg'):
              data_file.write(f'{os.path.join(f"{data_path}obj", image_file)}\n')
data_file.close()

# %% [markdown]
# Adjust yolov4-custom to trainning

# %%
with open('/content/darknet/cfg/yolov4.cfg', 'r+') as f:
    config_files = f.readlines()

config_files[1] = 'batch=64\n'
config_files[2] = 'subdivisions=64\n'


max_batches = 4000 if NUM_CLASSES==1 else NUM_CLASSES*2000
config_files[18] = f'max_batches={max_batches}\n'
config_files[20] = f'steps={max_batches*8//10},{max_batches*9//10}\n'


for i, line in enumerate(config_files):
    if line == '[yolo]\n':
        config_files[i-4] = f"filters={3*(5+NUM_CLASSES)}\n" # convolutional filters
        config_files[i+3] = f"classes={NUM_CLASSES}\n"       # yolo_classes


with open('/content/darknet/cfg/yolov4-custom.cfg', 'w+') as f:
    f.writelines(config_files)

# %% [markdown]
# Create Obj.data

# %%
with open('/content/darknet/data/obj.data', 'w+') as obj_data:
  odata = f"""classes={NUM_CLASSES}
  train=/content/darknet/data/train.txt
  valid=/content/darknet/data/test.txt
  names=/content/darknet/data/obj.names
  backup=/content/drive/MyDrive/Batman_Tracker_YoloV4_backup
  """
  obj_data.write(odata)

# %% [markdown]
# #Step 3: Model

# %% [markdown]
# Get pre-trained weights for yolo

# %%
# %cd /content/darknet
# !wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.conv.137

# %% [markdown]
# ### Train from scratch
#
# #####Use this code, so colab won't crash after being inactive for more than 10 mins;
#
#     function ClickConnect(){
#     console.log("Working");
#     document.querySelector("colab-toolbar-button#connect").click()
#     }
#     setInterval(ClickConnect,60000)

# %%
# !./darknet detector train /content/darknet/data/obj.data /content/darknet/cfg/yolov4-custom.cfg /content/darknet/yolov4.conv.137 -dont_show

# %%
imShow('chart.png')

# %% [markdown]
# ### Train from where you ceased training with saved weights.

# %%
# %cd /content/darknet
# !./darknet detector train /content/darknet/data/obj.data /content/darknet/cfg/yolov4-custom.cfg /content/drive/MyDrive/Batman_Tracker_YoloV4_backup/yolov4-custom_last.weights -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#  total_bbox = 27760, rewritten_bbox = 0.194524 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.000000), count: 1, class_loss = 0.000273, iou_loss = 0.000000, total_loss = 0.000273
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.666491), count: 7, class_loss = 6.966965, iou_loss = 0.964939, total_loss = 7.931904
#  total_bbox = 27767, rewritten_bbox = 0.194475 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.503049), count: 4, class_loss = 4.007915, iou_loss = 8.479912, total_loss = 12.487826
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.464209), count: 6, class_loss = 5.978901, iou_loss = 0.748066, total_loss = 6.726968
#  total_bbox = 27777, rewritten_bbox = 0.194405 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.000000), count: 1, class_loss = 0.000321, iou_loss = 0.000000, total_loss = 0.000321
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.542608), count: 5, class_loss = 4.982763, iou_loss = 0.494612, total_loss = 5.477375
#  total_bbox = 27782, rewritten_bbox = 0.194370 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 1.000000, iou_loss = 0.000000, total_loss = 1.000000
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.000000), count: 1, class_loss = 0.000262, iou_loss = 0.000000, total_loss = 0.000262
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.588589), count: 7, class_loss = 6.967121, iou_loss = 0.881326, total_loss = 7.848447
#  total_bbox = 27789, rewritten_bbox = 0.194321 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.576211), count: 2, class_loss = 2.001962, iou_loss = 2.324890, total_loss = 4.326852
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.457459), count: 9, class_loss = 8.945631, iou_loss = 0.976992, total_loss = 9.922623
#  total_bbox = 27800, rewritten_bbox = 0.194245 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.507749), count: 1, class_loss = 1.000151, iou_loss = 0.496470, total_loss = 1.496621
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.450453), count: 7, class_loss = 6.978343, iou_loss = 0.764749, total_loss = 7.743092
#  total_bbox = 27808, rewritten_bbox = 0.194189 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.340178), count: 1, class_loss = 1.000078, iou_loss = 0.166011, total_loss = 1.166089
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.422740), count: 7, class_loss = 6.979480, iou_loss = 0.422348, total_loss = 7.401827
#  total_bbox = 27816, rewritten_bbox = 0.194133 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.527768), count: 5, class_loss = 4.994853, iou_loss = 3.370922, total_loss = 8.365774
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.448835), count: 10, class_loss = 9.956711, iou_loss = 2.572188, total_loss = 12.528899
#  total_bbox = 27831, rewritten_bbox = 0.194028 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.754087), count: 1, class_loss = 1.000108, iou_loss = 2.145847, total_loss = 3.145954
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.379183), count: 6, class_loss = 5.984016, iou_loss = 0.756946, total_loss = 6.740963
#  total_bbox = 27838, rewritten_bbox = 0.193979 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.000000), count: 1, class_loss = 0.000250, iou_loss = 0.000000, total_loss = 0.000250
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0

# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.156289), count: 1, class_loss = 1.015125, iou_loss = 0.004218, total_loss = 1.019343
#  total_bbox = 27860, rewritten_bbox = 0.193826 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.000000), count: 1, class_loss = 0.000257, iou_loss = 0.000000, total_loss = 0.000257
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.346418), count: 1, class_loss = 1.013816, iou_loss = 0.020705, total_loss = 1.034522
#  total_bbox = 27861, rewritten_bbox = 0.193819 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.000000), count: 1, class_loss = 0.000278, iou_loss = 0.000000, total_loss = 0.000278
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.404464), count: 1, class_loss = 1.009460, iou_loss = 0.028230, total_loss = 1.037690
#  total_bbox = 27862, rewritten_bbox = 0.193812 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.000000), count: 1, class_loss = 0.000268, iou_loss = 0.000000, total_loss = 0.000268
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.531100), count: 3, class_loss = 2.988590, iou_loss = 1.004727, total_loss = 3.993318
#  total_bbox = 27865, rewritten_bbox = 0.193791 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.583361), count: 1, class_loss = 0.999901, iou_loss = 1.284351, total_loss = 2.284253
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.504880), count: 5, class_loss = 4.988986, iou_loss = 1.587931, total_loss = 6.576918
#  total_bbox = 27871, rewritten_bbox = 0.193750 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.000000), count: 1, class_loss = 0.000256, iou_loss = 0.000000, total_loss = 0.000256
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.196990), count: 1, class_loss = 1.016722, iou_loss = 0.006701, total_loss = 1.023423
#  total_bbox = 27872, rewritten_bbox = 0.193743 %
#
#  3980: 1.307611, 1.688990 avg loss, 0.000013 rate, 21.721733 seconds, 254720 images, 0.456930 hours left
# Resizing, random_coef = 1.40
#
#  896 x 896
# libpng warning: iCCP: known incorrect sRGB profile
#  try to allocate additional workspace_size = 104.00 MB
#  CUDA allocate done!
# Loaded: 3.981283 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.000000), count: 1, class_loss = 0.000240, iou_loss = 0.000000, total_loss = 0.000240
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.608576), count: 7, class_loss = 6.969465, iou_loss = 0.770719, total_loss = 7.740184
#  total_bbox = 27879, rewritten_bbox = 0.193694 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.554047), count: 1, class_loss = 1.000173, iou_loss = 1.158484, total_loss = 2.158657
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.523975), count: 9, class_loss = 8.963617, iou_loss = 1.508398, total_loss = 10.472015
#  total_bbox = 27889, rewritten_bbox = 0.193625 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 1.000000, iou_loss = 0.000000, total_loss = 1.000000
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.316513), count: 3, class_loss = 3.000573, iou_loss = 0.805199, total_loss = 3.805772
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.488559), count: 5, class_loss = 4.995646, iou_loss = 0.827924, total_loss = 5.823571
#  total_bbox = 27898, rewritten_bbox = 0.193562 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.586975), count: 1, class_loss = 1.000108, iou_loss = 1.300316, total_loss = 2.300425
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.489377), count: 9, class_loss = 8.962505, iou_loss = 1.329896, total_loss = 10.292401
#  total_bbox = 27908, rewritten_bbox = 0.193493 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.614641), count: 2, class_loss = 2.001879, iou_loss = 3.639037, total_loss = 5.640916
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.399940), count: 9, class_loss = 8.958296, iou_loss = 0.864668, total_loss = 9.822964
#  total_bbox = 27919, rewritten_bbox = 0.193417 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.000000), count: 1, class_loss = 0.000217, iou_loss = 0.000000, total_loss = 0.000217
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.587654), count: 7, class_loss = 6.966872, iou_loss = 0.814817, total_loss = 7.781689
#  total_bbox = 27926, rewritten_bbox = 0.193368 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 4, class_loss = 3.000000, iou_loss = 0.000001, total_loss = 3.000001
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.478323), count: 3, class_loss = 3.003849, iou_loss = 3.458428, total_loss = 6.462277
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0

# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.529033), count: 15, class_loss = 14.941088, iou_loss = 2.809916, total_loss = 17.751003
#  total_bbox = 34416, rewritten_bbox = 0.191771 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.000000), count: 1, class_loss = 0.000201, iou_loss = 0.000000, total_loss = 0.000201
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.531820), count: 5, class_loss = 4.984234, iou_loss = 0.530939, total_loss = 5.515173
#  total_bbox = 34421, rewritten_bbox = 0.191743 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.699473), count: 1, class_loss = 1.000165, iou_loss = 1.846534, total_loss = 2.846699
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.485828), count: 9, class_loss = 8.967043, iou_loss = 1.285687, total_loss = 10.252730
#  total_bbox = 34431, rewritten_bbox = 0.191688 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 1.000000, iou_loss = 0.000000, total_loss = 1.000000
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.535854), count: 9, class_loss = 9.012792, iou_loss = 15.695382, total_loss = 24.708174
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.354009), count: 13, class_loss = 12.963251, iou_loss = 2.050797, total_loss = 15.014049
#  total_bbox = 34454, rewritten_bbox = 0.191560 %
#
#  4000: 1.947283, 1.718103 avg loss, 0.000013 rate, 21.988553 seconds, 256000 images, 0.385245 hours left
# Saving weights to /content/drive/MyDrive/Batman_Tracker_YoloV4_backup/yolov4-custom_4000.weights
# Saving weights to /content/drive/MyDrive/Batman_Tracker_YoloV4_backup/yolov4-custom_last.weights
# Saving weights to /content/drive/MyDrive/Batman_Tracker_YoloV4_backup/yolov4-custom_final.weights
# If you want to train from the beginning, then use flag in the end of training command: -clear

# %%
imShow('chart.png')

# %% [markdown]
# Adjust yolov4-custom.cfg for testing

# %%
with open('/content/darknet/cfg/yolov4-custom.cfg', 'r+') as f:
    config_files = f.readlines()

config_files[1] = 'batch=1\n'
config_files[2] = 'subdivisions=1\n'

with open('/content/darknet/cfg/yolov4-custom.cfg', 'w+') as f:
    f.writelines(config_files)

# %% [markdown]
# ##Predict

# %% [markdown]
# ###Image Prediction

# %%
# %cd /content/darknet
# !./darknet detector test /content/darknet/data/obj.data /content/darknet/cfg/yolov4-custom.cfg /content/drive/MyDrive/Batman_Tracker_YoloV4_backup/yolov4-custom_last.weights /content/darknet/data/obj/11aSUPERMANBATMAN.jpg -thresh 0.2 -dont_show

# %%
imShow('predictions.jpg')

# %% [markdown]
# ###Video Prediction

# %%
# %cd /content/darknet
output_video = '/content/results.avi'

# !./darknet detector demo /content/darknet/data/obj.data /content/darknet/cfg/yolov4-custom.cfg /content/drive/MyDrive/Batman_Tracker_YoloV4_backup/yolov4-custom_last.weights /content/6.mp4 -dont_show -i 0 -out_filename $output_video

# %% [markdown]
# # ddddd

# %%
# %cd /content/darknet
# !./darknet detector test /content/darknet/data/obj.data /content/darknet/cfg/yolov4-custom.cfg /content/drive/MyDrive/Batman_Tracker_YoloV4_backup/yolov4-custom_last.weights /content/darknet/data/obj/200.jpg -thresh 0.2 -dont_show
imShow('predictions.jpg')
# Out:
# /content/darknet
#  CUDA-version: 11020 (11020), cuDNN: 8.1.1, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 64, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    608 x 608 x   3 ->  608 x 608 x  32 0.639 BF
#    1 conv     64       3 x 3/ 2    608 x 608 x  32 ->  304 x 304 x  64 3.407 BF
#    2 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    3 route  1 		                           ->  304 x 304 x  64
#    4 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    5 conv     32       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  32 0.379 BF
#    6 conv     64       3 x 3/ 1    304 x 304 x  32 ->  304 x 304 x  64 3.407 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 304 x 304 x  64 0.006 BF
#    8 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    9 route  8 2 	                           ->  304 x 304 x 128
#   10 conv     64       1 x 1/ 1    304 x 304 x 128 ->  304 x 304 x  64 1.514 BF
#   11 conv    128       3 x 3/ 2    304 x 304 x  64 ->  152 x 152 x 128 3.407 BF
#   12 conv     64       1 x 1/ 1    152 x 152 x 128 ->  152 x 152 x  64 0.379 BF
#   13 route  11 		                           ->  152 x 152 x 128
#   14 conv     64       1 x 1/ 1    152 x 152 x 128 ->  152 x 152 x  64 0.379 BF
#   15 conv     64       1 x 1/ 1    152 x 152 x  64 ->  152 x 152 x  64 0.189 BF
#   16 conv     64       3 x 3/ 1    152 x 152 x  64 ->  152 x 152 x  64 1.703 BF
#   17 Shortcut Layer: 14,  wt = 0, wn = 0, outputs: 152 x 152 x  64 0.001 BF
#   18 conv     64       1 x 1/ 1    152 x 152 x  64 ->  152 x 152 x  64 0.189 BF
#   19 conv     64       3 x 3/ 1    152 x 152 x  64 ->  152 x 152 x  64 1.703 BF
#   20 Shortcut Layer: 17,  wt = 0, wn = 0, outputs: 152 x 152 x  64 0.001 BF
#   21 conv     64       1 x 1/ 1    152 x 152 x  64 ->  152 x 152 x  64 0.189 BF
#   22 route  21 12 	                           ->  152 x 152 x 128
#   23 conv    128       1 x 1/ 1    152 x 152 x 128 ->  152 x 152 x 128 0.757 BF
#   24 conv    256       3 x 3/ 2    152 x 152 x 128 ->   76 x  76 x 256 3.407 BF
#   25 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   26 route  24 		                           ->   76 x  76 x 256
#   27 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   28 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   29 conv    128       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 128 1.703 BF
#   30 Shortcut Layer: 27,  wt = 0, wn = 0, outputs:  76 x  76 x 128 0.001 BF
#   31 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   32 conv    128       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 128 1.703 BF
#   33 Shortcut Layer: 30,  wt = 0, wn = 0, outputs:  76 x  76 x 128 0.001 BF
#   34 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   35 conv    128       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 128 1.703 BF
#   36 Shortcut Layer: 33,  wt = 0, wn = 0, outputs:  76 x  76 x 128 0.001 BF
#   37 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   38 conv    128       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 128 1.703 BF
#   39 Shortcut Layer: 36,  wt = 0, wn = 0, outputs:  76 x  76 x 128 0.001 BF
#   40 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   41 conv    128       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 128 1.703 BF
#   42 Shortcut Layer: 39,  wt = 0, wn = 0, outputs:  76 x  76 x 128 0.001 BF
#   43 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   44 conv    128       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 128 1.703 BF
#   45 Shortcut Layer: 42,  wt = 0, wn = 0, outputs:  76 x  76 x 128 0.001 BF
#   46 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   47 conv    128       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 128 1.703 BF
#   48 Shortcut Layer: 45,  wt = 0, wn = 0, outputs:  76 x  76 x 128 0.001 BF
#   49 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   50 conv    128       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 128 1.703 BF
#   51 Shortcut Layer: 48,  wt = 0, wn = 0, outputs:  76 x  76 x 128 0.001 BF
#   52 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   53 route  52 25 	                           ->   76 x  76 x 256
#   54 conv    256       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 256 0.757 BF
#   55 conv    512       3 x 3/ 2     76 x  76 x 256 ->   38 x  38 x 512 3.407 BF
#   56 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   57 route  55 		                           ->   38 x  38 x 512
#   58 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   59 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   60 conv    256       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 256 1.703 BF
#   61 Shortcut Layer: 58,  wt = 0, wn = 0, outputs:  38 x  38 x 256 0.000 BF
#   62 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   63 conv    256       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 256 1.703 BF
#   64 Shortcut Layer: 61,  wt = 0, wn = 0, outputs:  38 x  38 x 256 0.000 BF
#   65 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   66 conv    256       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 256 1.703 BF
#   67 Shortcut Layer: 64,  wt = 0, wn = 0, outputs:  38 x  38 x 256 0.000 BF
#   68 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   69 conv    256       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 256 1.703 BF
#   70 Shortcut Layer: 67,  wt = 0, wn = 0, outputs:  38 x  38 x 256 0.000 BF
#   71 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   72 conv    256       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 256 1.703 BF
#   73 Shortcut Layer: 70,  wt = 0, wn = 0, outputs:  38 x  38 x 256 0.000 BF
#   74 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   75 conv    256       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 256 1.703 BF
#   76 Shortcut Layer: 73,  wt = 0, wn = 0, outputs:  38 x  38 x 256 0.000 BF
#   77 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   78 conv    256       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 256 1.703 BF
#   79 Shortcut Layer: 76,  wt = 0, wn = 0, outputs:  38 x  38 x 256 0.000 BF
#   80 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   81 conv    256       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 256 1.703 BF
#   82 Shortcut Layer: 79,  wt = 0, wn = 0, outputs:  38 x  38 x 256 0.000 BF
#   83 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   84 route  83 56 	                           ->   38 x  38 x 512
#   85 conv    512       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 512 0.757 BF
#   86 conv   1024       3 x 3/ 2     38 x  38 x 512 ->   19 x  19 x1024 3.407 BF
#   87 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   88 route  86 		                           ->   19 x  19 x1024
#   89 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   90 conv    512       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x 512 0.189 BF
#   91 conv    512       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x 512 1.703 BF
#   92 Shortcut Layer: 89,  wt = 0, wn = 0, outputs:  19 x  19 x 512 0.000 BF
#   93 conv    512       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x 512 0.189 BF
#   94 conv    512       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x 512 1.703 BF
#   95 Shortcut Layer: 92,  wt = 0, wn = 0, outputs:  19 x  19 x 512 0.000 BF
#   96 conv    512       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x 512 0.189 BF
#   97 conv    512       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x 512 1.703 BF
#   98 Shortcut Layer: 95,  wt = 0, wn = 0, outputs:  19 x  19 x 512 0.000 BF
#   99 conv    512       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x 512 0.189 BF
#  100 conv    512       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x 512 1.703 BF
#  101 Shortcut Layer: 98,  wt = 0, wn = 0, outputs:  19 x  19 x 512 0.000 BF
#  102 conv    512       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x 512 0.189 BF
#  103 route  102 87 	                           ->   19 x  19 x1024
#  104 conv   1024       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x1024 0.757 BF
#  105 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#  106 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#  107 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#  108 max                5x 5/ 1     19 x  19 x 512 ->   19 x  19 x 512 0.005 BF
#  109 route  107 		                           ->   19 x  19 x 512
#  110 max                9x 9/ 1     19 x  19 x 512 ->   19 x  19 x 512 0.015 BF
#  111 route  107 		                           ->   19 x  19 x 512
#  112 max               13x13/ 1     19 x  19 x 512 ->   19 x  19 x 512 0.031 BF
#  113 route  112 110 108 107 	                   ->   19 x  19 x2048
#  114 conv    512       1 x 1/ 1     19 x  19 x2048 ->   19 x  19 x 512 0.757 BF
#  115 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#  116 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#  117 conv    256       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x 256 0.095 BF
#  118 upsample                 2x    19 x  19 x 256 ->   38 x  38 x 256
#  119 route  85 		                           ->   38 x  38 x 512
#  120 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#  121 route  120 118 	                           ->   38 x  38 x 512
#  122 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#  123 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#  124 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#  125 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#  126 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#  127 conv    128       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 128 0.095 BF
#  128 upsample                 2x    38 x  38 x 128 ->   76 x  76 x 128
#  129 route  54 		                           ->   76 x  76 x 256
#  130 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#  131 route  130 128 	                           ->   76 x  76 x 256
#  132 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#  133 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#  134 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#  135 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#  136 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#  137 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#  138 conv     18       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x  18 0.053 BF
#  139 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.20
# nms_kind: greedynms (1), beta = 0.600000
#  140 route  136 		                           ->   76 x  76 x 128
#  141 conv    256       3 x 3/ 2     76 x  76 x 128 ->   38 x  38 x 256 0.852 BF
#  142 route  141 126 	                           ->   38 x  38 x 512
#  143 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#  144 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#  145 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#  146 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#  147 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#  148 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#  149 conv     18       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x  18 0.027 BF
#  150 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.10
# nms_kind: greedynms (1), beta = 0.600000
#  151 route  147 		                           ->   38 x  38 x 256
#  152 conv    512       3 x 3/ 2     38 x  38 x 256 ->   19 x  19 x 512 0.852 BF
#  153 route  152 116 	                           ->   19 x  19 x1024
#  154 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#  155 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#  156 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#  157 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#  158 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#  159 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#  160 conv     18       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x  18 0.013 BF
#  161 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.05
# nms_kind: greedynms (1), beta = 0.600000
# Total BFLOPS 127.232
# avg_outputs = 1046213
#  Allocate additional workspace_size = 52.44 MB
# Loading weights from /content/drive/MyDrive/Batman_Tracker_YoloV4_backup/yolov4-custom_last.weights...
#  seen 64, trained: 256 K-images (4 Kilo-batches_64)
# Done! Loaded 162 layers from weights-file
#  Detection layer: 139 - type = 28
#  Detection layer: 150 - type = 28
#  Detection layer: 161 - type = 28
# /content/darknet/data/obj/200.jpg: Predicted in 78.136000 milli-seconds.

# %%
# %cd /content/darknet
output_video = '/content/drive/MyDrive/results_1.avi'

# !./darknet detector demo /content/darknet/data/obj.data /content/darknet/cfg/yolov4-custom.cfg /content/drive/MyDrive/Batman_Tracker_YoloV4_backup/yolov4-custom_last.weights /content/1.mp4 -dont_show -i 0 -out_filename $output_video
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
# FPS:20.9 	 AVG_FPS:21.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.9 	 AVG_FPS:21.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:21.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:21.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:21.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:21.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:21.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:21.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:21.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:21.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.8 	 AVG_FPS:21.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.8 	 AVG_FPS:21.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.9 	 AVG_FPS:21.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.9 	 AVG_FPS:21.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.9 	 AVG_FPS:21.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.9 	 AVG_FPS:21.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.9 	 AVG_FPS:21.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.9 	 AVG_FPS:21.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.9 	 AVG_FPS:21.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.0 	 AVG_FPS:21.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.0 	 AVG_FPS:21.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.0 	 AVG_FPS:21.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.8 	 AVG_FPS:21.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.0 	 AVG_FPS:21.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.0 	 AVG_FPS:21.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.9 	 AVG_FPS:21.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.0 	 AVG_FPS:21.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.8 	 AVG_FPS:21.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.8 	 AVG_FPS:21.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.9 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.9 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.0 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.0 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.0 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.0 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.1 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.0 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.0 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.0 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.0 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.1 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.0 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.0 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.0 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.1 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.1 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.1 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.1 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.1 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.0 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.9 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.0 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.0 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.0 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.0 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.1 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.1 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.1 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.1 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.1 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.2 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.1 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.2 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.0 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.1 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.1 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.1 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.1 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.1 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.1 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.1 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.0 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.0 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.0 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.0 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.0 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.1 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.1 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.0 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.9 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.0 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.8 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.8 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.8 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.8 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.8 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.9 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.9 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.9 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.9 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.9 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.9 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.9 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.8 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.8 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.8 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.8 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.8 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.9 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.8 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.8 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.8 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.8 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.9 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.9 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.0 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.9 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.9 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.9 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.9 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.9 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.9 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.9 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.9 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.0 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.0 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.9 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.8 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.8 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.8 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.8 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.9 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.9 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.9 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.9 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.9 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.9 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.8 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.9 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.8 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.8 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.9 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.6 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.6 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.8 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.8 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.8 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.9 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.9 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.9 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.9 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:21.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.8 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.8 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.8 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.8 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.8 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.8 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.8 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.9 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.9 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.8 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.8 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.8 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.8 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.8 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.8 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.8 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.6 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.8 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.6 	 AVG_FPS:21.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.6 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.5 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.6 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.6 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.8 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.8 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.8 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.8 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.6 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.6 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.6 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.6 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.6 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.5 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.6 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.8 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.9 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.9 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.8 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.8 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.8 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.8 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.8 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.6 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.6 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.6 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.5 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.6 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.5 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.5 	 AVG_FPS:20.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.5 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.5 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.6 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.5 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.5 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.6 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.8 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.9 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:20.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.9 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.9 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.8 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.8 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.6 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.8 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.9 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.6 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.6 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.5 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.5 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.4 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.5 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.4 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.5 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.5 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.5 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.5 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.4 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.6 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.8 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.9 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.5 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.8 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.8 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.6 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.6 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.5 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.5 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.4 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.4 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.4 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.4 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.3 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.3 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.3 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.4 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.3 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.3 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.3 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.3 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.3 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.2 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.2 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.1 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.2 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.0 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.1 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.1 	 AVG_FPS:21.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.1 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.1 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.1 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.1 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.1 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.2 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.2 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.2 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.4 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.5 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.6 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.8 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.9 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.9 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.9 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.8 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.6 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.5 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.5 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.5 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.4 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.4 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.3 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.3 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.3 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.2 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.2 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.1 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.1 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.1 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.1 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.2 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.2 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.2 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.0 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.2 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.2 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.2 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.9 	 AVG_FPS:20.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.3 	 AVG_FPS:20.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.3 	 AVG_FPS:20.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.4 	 AVG_FPS:20.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.6 	 AVG_FPS:20.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:20.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:20.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.8 	 AVG_FPS:20.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.9 	 AVG_FPS:20.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:20.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:20.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:20.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:20.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:20.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:20.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:20.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:20.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:20.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:20.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:20.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:20.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:20.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:20.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:20.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:20.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:20.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:20.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:20.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:20.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:20.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:20.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:20.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:20.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.4 	 AVG_FPS:20.6
#
#  cvWriteFrame
# Stream closed.
# input video stream closed.
#  closing... closed!output_video_writer closed.

# %%
# %cd /content/darknet
output_video = '/content/drive/MyDrive/results_2.avi'

# !./darknet detector demo /content/darknet/data/obj.data /content/darknet/cfg/yolov4-custom.cfg /content/drive/MyDrive/Batman_Tracker_YoloV4_backup/yolov4-custom_last.weights /content/2.mp4 -dont_show -i 0 -out_filename $output_video

# %%
# %cd /content/darknet
output_video = '/content/drive/MyDrive/results_3.avi'

# !./darknet detector demo /content/darknet/data/obj.data /content/darknet/cfg/yolov4-custom.cfg /content/drive/MyDrive/Batman_Tracker_YoloV4_backup/yolov4-custom_last.weights /content/3.mp4 -dont_show -i 0 -out_filename $output_video

# %%
# %cd /content/darknet
output_video = '/content/drive/MyDrive/results_4.avi'

# !./darknet detector demo /content/darknet/data/obj.data /content/darknet/cfg/yolov4-custom.cfg /content/drive/MyDrive/Batman_Tracker_YoloV4_backup/yolov4-custom_last.weights /content/4.mp4 -dont_show -i 0 -out_filename $output_video

# %%
# %cd /content/darknet
output_video = '/content/drive/MyDrive/results_5.avi'

# !./darknet detector demo /content/darknet/data/obj.data /content/darknet/cfg/yolov4-custom.cfg /content/drive/MyDrive/Batman_Tracker_YoloV4_backup/yolov4-custom_last.weights /content/5.mp4 -dont_show -i 0 -out_filename $output_video

# %%
# %cd /content/darknet
output_video = '/content/drive/MyDrive/results_6.avi'

# !./darknet detector demo /content/darknet/data/obj.data /content/darknet/cfg/yolov4-custom.cfg /content/drive/MyDrive/Batman_Tracker_YoloV4_backup/yolov4-custom_last.weights /content/6.mp4 -dont_show -i 0 -out_filename $output_video
